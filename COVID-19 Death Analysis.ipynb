# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import seaborn as sns

# %%
report=pd.read_csv('country_wise_latest.csv')

# %%
report
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
limited_report = report.sample(10)

# %%
sns.scatterplot(data=limited_report,y='Country/Region',x='Deaths',hue='WHO Region')
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
sns.barplot(data=report,x='Deaths',y='WHO Region',)
# Out:
# <Axes: xlabel='Deaths', ylabel='WHO Region'>

# %%
country_name='Eastern Mediterranean'
single_country=report[report['WHO Region']==country_name]

# %%
sns.scatterplot(data=single_country,x='WHO Region',y='Country/Region',hue='Deaths',style='Recovered')
# Out:
# <Axes: xlabel='WHO Region', ylabel='Country/Region'>

# %%
sns.barplot(data =single_country,y='Country/Region',x='Deaths')
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
country_name='Europe'
single_country=report[report['WHO Region']==country_name]

# %%
sns.scatterplot(data=single_country,x='Deaths',y='Country/Region',hue='Recovered',style='Recovered')
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
sns.barplot(data=single_country,x='Deaths',y='Country/Region')
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
country_name='Africa'
single_country=report[report['WHO Region']==country_name]

# %%
sns.scatterplot(data=single_country,y='Country/Region',x='Deaths',style='Recovered')
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
sns.barplot(data=single_country,y='Country/Region',x='Deaths')
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
unique_countries = report['WHO Region'].unique()

# %%
unique_countries
# Out:
# array(['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
#        'Western Pacific', 'South-East Asia'], dtype=object)

# %%
country_name='Americas'
single_country=report[report['WHO Region']==country_name]

# %%
sns.scatterplot(data=single_country, x= 'Deaths',y ='Country/Region',hue='Recovered',size='Deaths')
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
sns.barplot(data=single_country,y='Country/Region',x='Deaths')
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
country_name='Western Pacific'
single_country=report[report['WHO Region']==country_name]

# %%
sns.scatterplot(data=single_country,y='Country/Region',x='Deaths',hue='Recovered',style='WHO Region')
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
sns.barplot(data=single_country,y='Country/Region',x='Deaths')
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
sns.scatterplot(data=report,y='Deaths',x='Recovered',hue='WHO Region')
# Out:
# <Axes: xlabel='Recovered', ylabel='Deaths'>

# %%
sns.barplot(data=report,y='WHO Region',x='Deaths')
# Out:
# <Axes: xlabel='Deaths', ylabel='WHO Region'>

# %%
sns.scatterplot(data=report, x='WHO Region',y='Deaths',style='Recovered')
# Out:
# <Axes: xlabel='WHO Region', ylabel='Deaths'>

# %%
sns.barplot(report,y='WHO Region',x='Recovered')
# Out:
# <Axes: xlabel='Recovered', ylabel='WHO Region'>

# %%
country_name='South-East Asia'
single_country=report[report['WHO Region']==country_name]

# %%
sns.scatterplot(data=single_country,x='Active',y='Country/Region',hue='Recovered',style='Deaths')
# Out:
# <Axes: xlabel='Active', ylabel='Country/Region'>

# %%
sns.barplot(data=single_country,y='Country/Region',x='Deaths')
# Out:
# <Axes: xlabel='Deaths', ylabel='Country/Region'>

# %%
sns.barplot(data=single_country,y='Country/Region',x='Recovered')
# Out:
# <Axes: xlabel='Recovered', ylabel='Country/Region'>

# %%
sns.barplot(data=single_country,y='Country/Region',x='Active')
# Out:
# <Axes: xlabel='Active', ylabel='Country/Region'>

# %%
sns.heatmap(pd.crosstab(report['Active'],report['Recovered']))
# Out:
# <Axes: xlabel='Recovered', ylabel='Active'>

# %%
sns.heatmap(report.pivot_table(values='Deaths',index='WHO Region',columns='Country/Region'))
# Out:
# <Axes: xlabel='Country/Region', ylabel='WHO Region'>

# %%
sns.pairplot(report,hue='Deaths')
# Out:
# C:\Users\paula\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
country_name='India'
single_country=report[report['Country/Region']==country_name]

# %%
report['WHO Region'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
report['WHO Region'],report['Deaths'].value_counts('Deaths').plot(kind='bar')
# Out:
# (0      Eastern Mediterranean
#  1                     Europe
#  2                     Africa
#  3                     Europe
#  4                     Africa
#                 ...
#  182    Eastern Mediterranean
#  183                   Africa
#  184    Eastern Mediterranean
#  185                   Africa
#  186                   Africa
#  Name: WHO Region, Length: 187, dtype: object,
#  <Axes: xlabel='Deaths'>)
